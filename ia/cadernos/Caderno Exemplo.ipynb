# %%
import pandas as pd

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/dadosgovbr/catalogos-dados-brasil/refs/heads/master/dados/catalogos.csv')

# %%
dados
# Out:
#                                                Título  \
# 0                      Alagoas em dados e informações
# 1                             Fortaleza Dados Abertos
# 2                              Dados abertos – TCM-CE
# 3                      Dados abertos Distrito Federal
# 4                       Dados abertos – Governo do ES
# 5                  Dados abertos – Goiás Transparente
# 6                 Dados abertos – Assembleia de Minas
# 7                        Dados abertos – Estado de MG
# 8                    Dados abertos do SAGRES – TCE/PB
# 9               Dados abertos – Governo de Pernambuco
# 10                                       Dados Recife
# 11                             Dados Abertos Curitiba
# 12                                           data.rio
# 13  Dados Geográficos Abertos da Cidade do Rio de ...
# 14                                           Dados RS
# 15                                   Dados Abertos SC
# ...

# %%
dados['UF']
# Out:
# 0      AL
# 1      CE
# 2      CE
# 3      DF
# 4      ES
# 5      GO
# 6      MG
# 7      MG
# 8      PB
# 9      PE
# 10     PE
# 11     PR
# 12     RJ
# 13     RJ
# 14     RS
# 15     SC
# 16     RS
# 17     SP
# 18     SP
# 19    NaN
# 20    NaN
# 21     RS
# 22     RS
# 23     SP
# 24     RN
# 25     SP
# 26     MG
# 27     SP
# 28     GO
# 29     MT
# 30     PB
# 31     SP
# 32     MG
# 33     CE
# 34     RN
# 35     PE
# 36     PE
# 37     MG
# 38     DF
# Name: UF, dtype: object

# %%
dados.head()
# Out:
#                            Título  \
# 0  Alagoas em dados e informações
# 1         Fortaleza Dados Abertos
# 2          Dados abertos – TCM-CE
# 3  Dados abertos Distrito Federal
# 4   Dados abertos – Governo do ES
#
#                                                  URL  Município  UF  \
# 0                            http://dados.al.gov.br/        NaN  AL
# 1                  http://dados.fortaleza.ce.gov.br/  Fortaleza  CE
# 2                          http://api.tcm.ce.gov.br/        NaN  CE
# 3                            http://dados.df.gov.br/        NaN  DF
# 4  https://transparencia.es.gov.br/DadosAbertos/B...        NaN  ES
#
#       Esfera        Poder  Solução
# 0   Estadual    Executivo     CKAN
# 1  Municipal    Executivo     CKAN
# 2   Estadual  Legislativo  Interna
# 3   Estadual    Executivo     CKAN
# 4   Estadual    Executivo  Interna

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Título     39 non-null     object
#  1   URL        39 non-null     object
#  2   Município  14 non-null     object
#  3   UF         37 non-null     object
#  4   Esfera     39 non-null     object
#  5   Poder      38 non-null     object
#  6   Solução    39 non-null     object
# dtypes: object(7)
# memory usage: 2.3+ KB

# %%
dados.describe()
# Out:
#                                 Título                      URL  \
# count                               39                       39
# unique                              39                       39
# top     Alagoas em dados e informações  http://dados.al.gov.br/
# freq                                 1                        1
#
#              Município  UF    Esfera      Poder  Solução
# count               14  37        39         38       39
# unique              12  15         3          2        3
# top     Rio de Janeiro  SP  Estadual  Executivo  Interna
# freq                 2   6        23         24       23
